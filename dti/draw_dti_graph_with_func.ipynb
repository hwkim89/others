# %%
from visualization.utils import draw_dti_graph

# %%
pred_dtis_path, output_dir = './data/pred_dtis.csv', './dti_graphs'
# drug = 'CC1=NC=C(COP(O)(O)=O)C(C=O)=C1O'
# drug = 'CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C=C3)O2)C(C)=C1O'
drug = 'N[C@@H](CCC(O)=O)C(O)=O'
graph_fname = draw_dti_graph(pred_dtis_path, drug,
                             target_col='protein name',
                             drug_col='SMILES',
                             aff_score_col='Prediction',
                             smiles2dname=True,
                             prev_cov=True,
                             output_dir=output_dir)

print(f'DTI graph file name: {graph_fname}')
# Out:
# # of targets: 5, # of drugs: 97
# DTI sample: [('3C-like\nproteinase', 4.4992), ('RNA-dependent\nRNA\npolymerase', 7.2317), ('helicase', 5.0056), ('endoRNAse', 5.2326), ('2-O-ribose\nmethyltransferase', 6.3463)]
# dti_graph_for_Glutamic acid.png is saved.
# DTI graph file name: dti_graph_for_Glutamic acid.png

# %%
# from visualization.utils import draw_dti_graph
# import pandas as pd

# smiles_list = list(set(pd.read_csv('data/pred_dtis.csv', usecols=('SMILES',))['SMILES'].tolist()))

# pred_dtis_path, output_dir = 'data/pred_dtis.csv', 'dti_graphs'
# for smiles in smiles_list:
#     graph_fname = draw_dti_graph(pred_dtis_path, smiles,
#                                  target_col='protein name',
#                                  drug_col='SMILES',
#                                  aff_score_col='Prediction',
#                                  smiles2dname=True,
#                                  prev_cov=True,
#                                  output_dir=output_dir)
    
# print(f'DTI graph file name: {graph_fname}')
